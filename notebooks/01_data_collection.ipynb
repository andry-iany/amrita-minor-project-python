# %% [markdown]
# # Data collection

# %%
import os
from dotenv import load_dotenv
import kagglehub

# %%
# load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# download dataset from Kaggle
path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\andry\.cache\kagglehub\datasets\lakshmi25npathi\imdb-dataset-of-50k-movie-reviews\versions\1

# %%
## Copy downloaded dataset to 'data/raw/' folder
import shutil
from sentiment_analysis.utils import PATH_TRAINING_DATASET

source = os.path.join(path, 'IMDB Dataset.csv')

shutil.copyfile(source, PATH_TRAINING_DATASET)
# Out:
# 'C:\\mine\\learn\\amrita\\minor-project\\project\\data\\raw\\IMDB Dataset.csv'
